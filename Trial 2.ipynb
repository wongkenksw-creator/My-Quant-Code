# 2010-01-07  6109268  13234600  50559700  131091100
# 2010-01-08  4390271  28712400  51197400  126402800
# ...             ...       ...       ...        ...
# 2020-12-24  1842111   3265500  10550600   26457900
# 2020-12-28  3781499   9020500  17933500   39000400
# 2020-12-29  3647402   8320600  17403200   53680500
# 2020-12-30  3535794   8142700  20272300   49455300
# 2020-12-31  3738822   8495000  20942100   78520700
#
# [2769 rows x 30 columns]

# %%
close=stocks.loc[:,"Close"].copy()
close
# Out:
# Ticker            AAPL         DIS        IBM         KO        MSFT  \
# Date
# 2010-01-04    6.431895   27.593048  73.778824  17.692513   23.211439
# 2010-01-05    6.443017   27.524218  72.887566  17.478493   23.218946
# 2010-01-06    6.340532   27.377943  72.414062  17.472288   23.076448
# 2010-01-07    6.328811   27.386549  72.163422  17.428865   22.836458
# 2010-01-08    6.370885   27.429571  72.887566  17.106274   22.993950
# ...                ...         ...        ...        ...         ...
# 2020-12-24  128.737015  171.610001  98.111931  46.655010  214.489517
# 2020-12-28  133.341324  176.677399  98.214249  47.283596  216.617569
# 2020-12-29  131.565933  175.136444  97.411636  47.257404  215.837616
# 2020-12-30  130.444107  178.959198  97.836525  47.528038  213.459229
# 2020-12-31  129.439346  178.969086  99.048279  47.877262  214.171768
#
# Ticker             SPY
# Date
# 2010-01-04   85.768448
# 2010-01-05   85.995529
# 2010-01-06   86.056053
# 2010-01-07   86.419296
# 2010-01-08   86.706894
# ...                ...
# 2020-12-24  347.452515
# 2020-12-28  350.437469
# 2020-12-29  349.768890
# 2020-12-30  350.267914
# 2020-12-31  352.047577
#
# [2769 rows x 6 columns]

# %%
normclose=close.div(close.iloc[0]).mul(100)
normclose
# Out:
# Ticker             AAPL         DIS         IBM          KO        MSFT  \
# Date
# 2010-01-04   100.000000  100.000000  100.000000  100.000000  100.000000
# 2010-01-05   100.172916   99.750551   98.791986   98.790337  100.032343
# 2010-01-06    98.579540   99.220437   98.150199   98.755268   99.418430
# 2010-01-07    98.397306   99.251626   97.810480   98.509838   98.384499
# 2010-01-08    99.051448   99.407543   98.791986   96.686514   99.063008
# ...                 ...         ...         ...         ...         ...
# 2020-12-24  2001.541057  621.932017  132.981153  263.699179  924.068154
# 2020-12-28  2073.126636  640.296781  133.119835  267.252014  933.236271
# 2020-12-29  2045.523718  634.712205  132.031972  267.103976  929.876061
# 2020-12-30  2028.082105  648.566253  132.607867  268.633627  919.629443
# 2020-12-31  2012.460570  648.602087  134.250282  270.607479  922.699222
#
# Ticker             SPY
# Date
# 2010-01-04  100.000000
# 2010-01-05  100.264761
# 2010-01-06  100.335328
# 2010-01-07  100.758844
# 2010-01-08  101.094162
# ...                ...
# 2020-12-24  405.105284
# 2020-12-28  408.585533
# 2020-12-29  407.806016
# 2020-12-30  408.387842
# 2020-12-31  410.462805
#
# [2769 rows x 6 columns]

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002494 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003461 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006649  0.001571  0.010035 -0.018509  0.006896  0.003327
# 2010-01-11 -0.008822 -0.016311 -0.010470  0.020308 -0.012720  0.001397

# %%
ret.describe()
# Out:
# Ticker         AAPL          DIS          IBM           KO         MSFT  \
# count   2768.000000  2768.000000  2768.000000  2768.000000  2768.000000
# mean       0.001244     0.000798     0.000206     0.000421     0.000931
# std        0.017830     0.015702     0.014090     0.011053     0.015993
# min       -0.128647    -0.129846    -0.128507    -0.096725    -0.147391
# 25%       -0.006954    -0.006172    -0.006144    -0.004520    -0.006807
# 50%        0.000961     0.000684     0.000392     0.000484     0.000689
# 75%        0.010409     0.007913     0.006829     0.005735     0.008671
# max        0.119808     0.144123     0.113011     0.064796     0.142169
#
# Ticker          SPY
# count   2768.000000
# mean       0.000570
# std        0.010870
# min       -0.109424
# 25%       -0.003422
# 50%        0.000699
# 75%        0.005452
# max        0.090603

# %%
ret.describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# Ticker
# AAPL    2768.0  0.001244  0.017830 -0.128647 -0.006954  0.000961  0.010409
# DIS     2768.0  0.000798  0.015702 -0.129846 -0.006172  0.000684  0.007913
# IBM     2768.0  0.000206  0.014090 -0.128507 -0.006144  0.000392  0.006829
# KO      2768.0  0.000421  0.011053 -0.096725 -0.004520  0.000484  0.005735
# MSFT    2768.0  0.000931  0.015993 -0.147391 -0.006807  0.000689  0.008671
# SPY     2768.0  0.000570  0.010870 -0.109424 -0.003422  0.000699  0.005452
#
#              max
# Ticker
# AAPL    0.119808
# DIS     0.144123
# IBM     0.113011
# KO      0.064796
# MSFT    0.142169
# SPY     0.090603

# %%
summary=ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.001244  0.017830
# DIS     0.000798  0.015702
# IBM     0.000206  0.014090
# KO      0.000421  0.011053
# MSFT    0.000931  0.015993
# SPY     0.000570  0.010870

# %%
summary["mean"]=summary["mean"]*252
summary["std"]=summary["std"]*np.sqrt(252)
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.313545  0.283050
# DIS     0.201212  0.249255
# IBM     0.051943  0.223671
# KO      0.106110  0.175462
# MSFT    0.234610  0.253888
# SPY     0.143546  0.172551

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
# Out:
# <Axes: xlabel='std', ylabel='mean'>

# %%
#which dot is which stock
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
plt.xlabel("Annual risk(std)",fontsize=15)
plt.ylabel("Annual return",fontsize=15)
plt.title("Risk/return",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Risk/return')

# %%
fruits=["apple","banana","mango"]
for i in fruits:
    print(i)
# Out:
# apple
# banana
# mango

# %%
fruits[1]
# Out:
# 'banana'

# %% [markdown]
# #Correlation and covariance

# %%
#comment

# %%
ret
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002494 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003461 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006649  0.001571  0.010035 -0.018509  0.006896  0.003327
# 2010-01-11 -0.008822 -0.016311 -0.010470  0.020308 -0.012720  0.001397
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-24  0.007712  0.001037  0.006376  0.006782  0.007828  0.003890
# 2020-12-28  0.035765  0.029529  0.001043  0.013473  0.009921  0.008591
# 2020-12-29 -0.013315 -0.008722 -0.008172 -0.000554 -0.003601 -0.001908
# 2020-12-30 -0.008527  0.021827  0.004361  0.005727 -0.011019  0.001427
# 2020-12-31 -0.007703  0.000055  0.012385  0.007347  0.003338  0.005081
#
# [2768 rows x 6 columns]

# %%
ret.cov()
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    0.000318  0.000115  0.000110  0.000068  0.000159  0.000128
# DIS     0.000115  0.000247  0.000111  0.000086  0.000121  0.000121
# IBM     0.000110  0.000111  0.000199  0.000079  0.000120  0.000108
# KO      0.000068  0.000086  0.000079  0.000122  0.000077  0.000078
# MSFT    0.000159  0.000121  0.000120  0.000077  0.000256  0.000130
# SPY     0.000128  0.000121  0.000108  0.000078  0.000130  0.000118

# %%
ret.corr()
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    1.000000  0.409407  0.435915  0.345102  0.556477  0.659223
# DIS     0.409407  1.000000  0.501432  0.493057  0.480983  0.706340
# IBM     0.435915  0.501432  1.000000  0.509001  0.533283  0.704533
# KO      0.345102  0.493057  0.509001  1.000000  0.435529  0.645946
# MSFT    0.556477  0.480983  0.533283  0.435529  1.000000  0.746678
# SPY     0.659223  0.706340  0.704533  0.645946  0.746678  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True,annot_kws={"size":15},vmax=0.6)
plt.show()
#have profolio that with stocks lower than 0.5

# %%
#challange

# %%
ticker=["SPY","AAPL","KO","IBM","DIS","MSFT","AMD","NVDA","AVGO","TSM","GOOGL","AMZN","META","PLTR","QQQ","TSLA"]
stocks = yf.download(ticker, start = "2024-06-01",end ="2025-06-01")
stocks
# Out:
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/2410806363.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stocks = yf.download(ticker, start = "2024-06-01",end ="2025-06-01")
# [*********************100%***********************]  16 of 16 completed
# Price            Close                                                  \
# Ticker            AAPL         AMD        AMZN        AVGO         DIS
# Date
# 2024-06-03  193.126816  163.550003  178.339996  130.593475  101.846756
# 2024-06-04  193.445312  159.990005  179.339996  131.474701  102.401726
# 2024-06-05  194.958237  166.169998  181.279999  139.602341  100.588173
# 2024-06-06  193.574722  166.779999  185.000000  138.434601  100.300766
# 2024-06-07  195.973480  167.869995  184.300003  138.965118  100.627815
# ...                ...         ...         ...         ...         ...
# 2025-05-23  195.270004  110.309998  200.990005  228.720001  109.720001
# 2025-05-27  200.210007  114.559998  206.020004  235.649994  112.360001
# 2025-05-28  200.419998  112.860001  204.720001  239.429993  111.519997
# 2025-05-29  199.949997  113.029999  205.699997  241.970001  112.019997
# 2024-06-10  0.002176 -0.005007  0.019555  0.009484  0.007461 -0.007722
#
# Ticker           QQQ       SPY      TSLA       TSM
# Date
# 2024-06-04  0.002737  0.001118 -0.008622 -0.016005
# 2024-06-05  0.020160  0.011885  0.001316  0.068538
# 2024-06-06 -0.000345 -0.000018  0.016800 -0.005217
# 2024-06-07 -0.000885 -0.001216 -0.002585  0.014315
# 2024-06-10  0.004039  0.003090 -0.020791  0.022933

# %%
summary=ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.000375  0.020970
# AMD    -0.001023  0.033439
# AMZN    0.000801  0.021917
# AVGO    0.003269  0.039924
# DIS     0.000602  0.019199
# GOOGL   0.000183  0.019882
# IBM     0.002086  0.017582
# KO      0.000725  0.010769
# META    0.001513  0.023373
# MSFT    0.000593  0.016199
# NVDA    0.001341  0.037158
# PLTR    0.008386  0.045914
# QQQ     0.000702  0.016197
# SPY     0.000579  0.012925
# TSLA    0.003754  0.045879
# TSM     0.001380  0.029392

# %%
summary["mean"]=summary["mean"]*252
summary["std"]=summary["std"]*np.sqrt(252)
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.094393  0.332881
# AMD    -0.257855  0.530823
# AMZN    0.201796  0.347924
# AVGO    0.823785  0.633770
# DIS     0.151762  0.304782
# GOOGL   0.046124  0.315612
# IBM     0.525771  0.279110
# KO      0.182762  0.170950
# META    0.381279  0.371042
# MSFT    0.149496  0.257145
# NVDA    0.338014  0.589859
# PLTR    2.113228  0.728869
# QQQ     0.176982  0.257125
# SPY     0.145792  0.205172
# TSLA    0.946120  0.728301
# TSM     0.347759  0.466577

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
# Out:
# <Axes: xlabel='std', ylabel='mean'>

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]),size=10)
plt.xlabel("Annual risk(std)",fontsize=15)
plt.ylabel("Annual return",fontsize=15)
plt.title("Risk/return",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Risk/return')

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Greys",annot=True,annot_kws={"size":10},vmax=0.8)
plt.title("Correlation",fontsize=25)
plt.show()

# %%
#simple return and log return

# %%
df=pd.DataFrame(index=[2016,2017,2018],data=[100,50,95],columns=["Price"])
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturns=df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
100*1.2*1.2
# Out:
# 144.0

# %%
#mean return are misleading as crazy

# %%
logreturns=np.log(df/df.shift(1))
logreturns
# Out:
#          Price
# 2016       NaN
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %%
SPY = yf.download("SPY")
SPY
# Out:
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/452599375.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   SPY = yf.download("SPY")
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker             SPY         SPY         SPY         SPY       SPY
# Date
# 1993-01-29   24.452515   24.469906   24.348165   24.469906   1003200
# 1993-02-01   24.626438   24.626438   24.469914   24.469914    480500
# 1993-02-02   24.678612   24.696003   24.556871   24.609046    201300
# 1993-02-03   24.939478   24.956869   24.695996   24.713388    529400
# 1993-02-04   25.043829   25.096004   24.748173   25.026437    531500
# ...                ...         ...         ...         ...       ...
# 2025-06-10  603.080017  603.469971  599.090027  600.219971  66247000
# 2025-06-11  601.359985  605.059998  599.270020  604.190002  73658200
# 2025-06-12  603.750000  603.750000  599.520020  600.010010  64129000
# 2025-06-13  597.000000  601.849976  595.479980  598.500000  89506000
# 2025-06-16  602.679993  604.450012  600.219971  600.400024  79133100
#
# [8151 rows x 5 columns]

# %%
spy=SPY.Close

# %%
spy
# Out:
# Ticker             SPY
# Date
# 1993-01-29   24.452515
# 1993-02-01   24.626438
# 1993-02-02   24.678612
# 1993-02-03   24.939478
# 1993-02-04   25.043829
# ...                ...
# 2025-06-10  603.080017
# 2025-06-11  601.359985
# 2025-06-12  603.750000
# 2025-06-13  597.000000
# 2025-06-16  602.679993
#
# [8151 rows x 1 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()

# %%
#create MA

# %%
spy_roll=spy.rolling(window=10)
spy_roll
# Out:
# Rolling [window=10,center=False,axis=0,method=single]

# %%
spy_roll=spy_roll.mean()

# %%
spy_roll
# Out:
# Ticker             SPY
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2025-06-10  594.685004
# 2025-06-11  596.048004
# 2025-06-12  597.418005
# 2025-06-13  598.179004
# 2025-06-16  599.176001
#
# [8151 rows x 1 columns]

# %%
spy_roll.head(15)
# Out:
# Ticker            SPY
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  24.854263
# 1993-02-12  24.890785
# 1993-02-16  24.847306
# 1993-02-17  24.796869
# 1993-02-18  24.718606
# 1993-02-19  24.638605

# %%
spy.rolling(window=10).median()
# Out:
# Ticker             SPY
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2025-06-10  594.489990
# 2025-06-11  596.010010
# 2025-06-12  597.615021
# 2025-06-13  598.070007
# 2025-06-16  599.410004
#
# [8151 rows x 1 columns]

# %%
spy.rolling(window=10).max()
# Out:
# Ticker             SPY
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2025-06-10  603.080017
# 2025-06-11  603.080017
# 2025-06-12  603.750000
# 2025-06-13  603.750000
# 2025-06-16  603.750000
#
# [8151 rows x 1 columns]

# %%
spy.rolling(window=10,min_periods=5).max().head(15)
# Out:
# Ticker            SPY
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04  25.043837
# 1993-02-05  25.043837
# 1993-02-08  25.043837
# 1993-02-09  25.043837
# 1993-02-10  25.043837
# 1993-02-11  25.043837
# 1993-02-12  25.043837
# 1993-02-16  25.043837
# 1993-02-17  25.043837
# 1993-02-18  25.043837
# 1993-02-19  25.026434

# %%
spy["SMA50"] = spy["SPY"].rolling(window=50, min_periods=50).mean()
spy.head(52)
# Out:
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/2240802088.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["SMA50"] = spy["SPY"].rolling(window=50, min_periods=50).mean()
# Ticker            SPY      SMA50
# Date
# 1993-01-29  24.452515        NaN
# 1993-02-01  24.626438        NaN
# 1993-02-02  24.678612        NaN
# 1993-02-03  24.939478        NaN
# 1993-02-04  25.043829        NaN
# 1993-02-05  25.026442        NaN
# 1993-02-08  25.026442        NaN
# 1993-02-09  24.852537        NaN
# 1993-02-10  24.887300        NaN
# 1993-02-11  25.009058        NaN
# 1993-02-12  24.817739        NaN
# 1993-02-16  24.191656        NaN
# 1993-02-17  24.174250        NaN
# 1993-02-18  24.156857        NaN
# 1993-02-19  24.243813        NaN
# 1993-02-22  24.330795        NaN
# 1993-02-23  24.313393        NaN
# 1993-02-24  24.626438        NaN
# 1993-02-25  24.678612        NaN
# 1993-02-26  24.713381        NaN
# 1993-03-01  24.643829        NaN
# 1993-03-02  25.009058        NaN
# 1993-03-03  25.113403        NaN
# 1993-03-04  24.974264        NaN
# 1993-03-05  24.904701        NaN
# 1993-03-08  25.461231        NaN
# 1993-03-09  25.374262        NaN
# 1993-03-10  25.426449        NaN
# 1993-03-11  25.356880        NaN
# 1993-03-12  25.096003        NaN
# 1993-03-15  25.217751        NaN
# 1993-03-16  25.217751        NaN
# 1993-03-17  25.061214        NaN
# 1993-03-18  25.217751        NaN
# 1993-03-19  25.179577        NaN
# 1993-03-22  25.039801        NaN
# 1993-03-23  25.092228        NaN
# 1993-03-24  25.092228        NaN
# 1993-03-25  25.249474        NaN
# 1993-03-26  25.109690        NaN
# 1993-03-29  25.214531        NaN
# 1993-03-30  25.284431        NaN
# 1993-03-31  25.266956        NaN
# 1993-04-01  25.179577        NaN
# 1993-04-02  24.655375        NaN
# 1993-04-05  24.777697        NaN
# 1993-04-06  24.707783        NaN
# 1993-04-07  24.795162        NaN
# 1993-04-08  24.760229        NaN
# 1993-04-12  25.109690  24.907571
# 1993-04-13  25.162098  24.921763
# 1993-04-14  25.127159  24.931777

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()

# %%
spy["SMA200"] = spy["SPY"].rolling(window=200, min_periods=200).mean()
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()
# Out:
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/3922899000.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["SMA200"] = spy["SPY"].rolling(window=200, min_periods=200).mean()

# %%
#challange2 draw MA

# %%
NVDA = yf.download("NVDA")
nvda = NVDA.Close
nvda["SMA50"] = nvda.NVDA.rolling(window=50, min_periods=50).mean()
nvda["SMA200"] = nvda.NVDA.rolling(window=200, min_periods=200).mean()
nvda.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()
# Out:
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/4286024605.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   NVDA = yf.download("NVDA")
# [*********************100%***********************]  1 of 1 completed
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/4286024605.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nvda["SMA50"] = nvda.NVDA.rolling(window=50, min_periods=50).mean()
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/4286024605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nvda["SMA200"] = nvda.NVDA.rolling(window=200, min_periods=200).mean()

# %%
TSLA = yf.download("TSLA")
tsla = TSLA.Close
tsla["SMA50"] = tsla.TSLA.rolling(window=50, min_periods=50).mean()
tsla["SMA200"] = tsla.TSLA.rolling(window=200, min_periods=200).mean()
tsla.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()
# Out:
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/3182601785.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   TSLA = yf.download("TSLA")
# [*********************100%***********************]  1 of 1 completed
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/3182601785.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tsla["SMA50"] = tsla.TSLA.rolling(window=50, min_periods=50).mean()
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/3182601785.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tsla["SMA200"] = tsla.TSLA.rolling(window=200, min_periods=200).mean()

# %%
PLTR = yf.download("PLTR")
pltr = PLTR.Close
pltr["SMA50"] = pltr.PLTR.rolling(window=50, min_periods=50).mean()
pltr["SMA200"] = pltr.PLTR.rolling(window=200, min_periods=200).mean()
pltr.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()
# Out:
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/2416543251.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   PLTR = yf.download("PLTR")
# [*********************100%***********************]  1 of 1 completed
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/2416543251.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pltr["SMA50"] = pltr.PLTR.rolling(window=50, min_periods=50).mean()
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/2416543251.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pltr["SMA200"] = pltr.PLTR.rolling(window=200, min_periods=200).mean()

# %%
#EMA（近期數據更重要）

# %%
PLTR = yf.download("PLTR")
pltr = PLTR.Close
pltr["EMA50"] = pltr.PLTR.ewm(span=50, min_periods=50).mean()
pltr["EMA200"] = pltr.PLTR.ewm(span=200, min_periods=200).mean()
pltr.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()
# Out:
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/3868395524.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   PLTR = yf.download("PLTR")
# [*********************100%***********************]  1 of 1 completed
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/3868395524.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pltr["EMA50"] = pltr.PLTR.ewm(span=50, min_periods=50).mean()
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/3868395524.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pltr["EMA200"] = pltr.PLTR.ewm(span=200, min_periods=200).mean()

# %%
#know which day is which星期/季

# %%
spy["Day"]=spy.index.day_name()
# Out:
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/4201293564.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["Day"]=spy.index.day_name()

# %%
spy
# Out:
# Ticker             SPY       SMA50      SMA200        Day
# Date
# 1993-01-29   24.452515         NaN         NaN     Friday
# 1993-02-01   24.626438         NaN         NaN     Monday
# 1993-02-02   24.678612         NaN         NaN    Tuesday
# 1993-02-03   24.939478         NaN         NaN  Wednesday
# 1993-02-04   25.043829         NaN         NaN   Thursday
# ...                ...         ...         ...        ...
# 2025-06-10  603.080017  562.963601  576.262629    Tuesday
# 2025-06-11  601.359985  563.803000  576.514421  Wednesday
# 2025-06-12  603.750000  564.658601  576.748891   Thursday
# 2025-06-13  597.000000  565.308201  576.956248     Friday
# 2025-06-16  602.679993  566.627800  577.188191     Monday
#
# [8151 rows x 4 columns]

# %%
spy["Day"]=spy.index.quarter
# Out:
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/1375839149.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["Day"]=spy.index.quarter

# %%
spy
# Out:
# Ticker             SPY       SMA50      SMA200  Day
# Date
# 1993-01-29   24.452515         NaN         NaN    1
# 1993-02-01   24.626438         NaN         NaN    1
# 1993-02-02   24.678612         NaN         NaN    1
# 1993-02-03   24.939478         NaN         NaN    1
# 1993-02-04   25.043829         NaN         NaN    1
# ...                ...         ...         ...  ...
# 2025-06-10  603.080017  562.963601  576.262629    2
# 2025-06-11  601.359985  563.803000  576.514421    2
# 2025-06-12  603.750000  564.658601  576.748891    2
# 2025-06-13  597.000000  565.308201  576.956248    2
# 2025-06-16  602.679993  566.627800  577.188191    2
#
# [8151 rows x 4 columns]

# %%
#Let all the day in data frame

# %%
SPY=yf.download("SPY")
# Out:
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/732262872.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   SPY=yf.download("SPY")
# [*********************100%***********************]  1 of 1 completed

# %%
spy=SPY.Close

# %%
all_days=pd.date_range(start="2010-12-31",end="2020-01-01",freq="D")

# %%
spy
# Out:
# Ticker             SPY
# Date
# 1993-01-29   24.452518
# 1993-02-01   24.626446
# 1993-02-02   24.678616
# 1993-02-03   24.939482
# 1993-02-04   25.043839
# ...                ...
# 2025-06-11  601.359985
# 2025-06-12  603.750000
# 2025-06-13  597.000000
# 2025-06-16  602.679993
# 2025-06-17  597.530029
#
# [8152 rows x 1 columns]

# %%
spy=spy.reindex(all_days)

# %%
spy
# Out:
# Ticker             SPY
# 2010-12-31   97.036148
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03   98.039314
# 2011-01-04   97.985291
# ...                ...
# 2019-12-28         NaN
# 2019-12-29         NaN
# 2019-12-30  296.788300
# 2019-12-31  297.509216
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
spy.fillna(method="ffill")
# Out:
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/3731869003.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spy.fillna(method="ffill")
# Ticker             SPY
# 2010-12-31   97.036148
# 2011-01-01   97.036148
# 2011-01-02   97.036148
# 2011-01-03   98.039314
# 2011-01-04   97.985291
# ...                ...
# 2019-12-28  298.433655
# 2019-12-29  298.433655
# 2019-12-30  296.788300
# 2019-12-31  297.509216
# 2020-01-01  297.509216
#
# [3289 rows x 1 columns]

# %%
spy.fillna(method="bfill")
# Out:
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/1752721331.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spy.fillna(method="bfill")
# Ticker             SPY
# 2010-12-31   97.036148
# 2011-01-01   98.039314
# 2011-01-02   98.039314
# 2011-01-03   98.039314
# 2011-01-04   97.985291
# ...                ...
# 2019-12-28  296.788300
# 2019-12-29  296.788300
# 2019-12-30  296.788300
# 2019-12-31  297.509216
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
#get data with week and month

# %%
SPY=yf.download("SPY",interval="1wk")
# Out:
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/1247280329.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   SPY=yf.download("SPY",interval="1wk")
# [*********************100%***********************]  1 of 1 completed

# %%
SPY
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker             SPY         SPY         SPY         SPY        SPY
# Date
# 1993-01-25   24.452530   24.469921   24.348181   24.469921    1003200
# 1993-02-01   25.026461   25.096027   24.469931   24.469931    2234800
# 1993-02-08   24.817736   25.113392   24.782953   25.026434    1159800
# 1993-02-15   24.243803   24.748158   23.826406   24.748158     998700
# 1993-02-22   24.713394   24.730786   24.191648   24.313388    1024300
# ...                ...         ...         ...         ...        ...
# 2025-05-19  579.109985  595.539978  575.599976  588.099976  370870100
# 2025-05-26  589.390015  593.200012  578.429993  586.070007  301608500
# 2025-06-02  599.140015  600.830017  585.059998  587.760010  341418300
# 2025-06-09  597.000000  605.059998  595.479980  599.719971  346556600
# 2025-06-16  597.530029  604.450012  596.760010  600.400024  243193933
#
# [1691 rows x 5 columns]

# %%
#Cummaltive Return,drawdowns

# %%
apple=yf.download("AAPL")
# Out:
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/2880766964.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   apple=yf.download("AAPL")
# [*********************100%***********************]  1 of 1 completed

# %%
apple=apple.Close

# %%
apple["d_returns"]=np.log(apple.div(apple.shift(1)))

# %%
apple
# Out:
# Ticker            AAPL  d_returns
# Date
# 1980-12-12    0.098597        NaN
# 1980-12-15    0.093453  -0.053581
# 1980-12-16    0.086594  -0.076231
# 1980-12-17    0.088737   0.024450
# 1980-12-18    0.091310   0.028580
# ...                ...        ...
# 2025-06-11  198.779999  -0.019380
# 2025-06-12  199.199997   0.002111
# 2025-06-13  196.449997  -0.013901
# 2025-06-16  198.419998   0.009978
# 2025-06-17  195.639999  -0.014110
#
# [11219 rows x 2 columns]

# %%
apple.dropna(inplace=True)

# %%
apple.d_returns.sum()
# Out:
# 7.592994554981297

# %%
np.exp(apple.d_returns.sum())
# Out:
# 1984.246561318192

# %%
apple["cummreturns"]=apple.d_returns.cumsum().apply(np.exp)

# %%
apple
# Out:
# Ticker            AAPL  d_returns  cummreturns
# Date
# 1980-12-15    0.093453  -0.053581     0.947829
# 1980-12-16    0.086594  -0.076231     0.878261
# 1980-12-17    0.088737   0.024450     0.899999
# 1980-12-18    0.091310   0.028580     0.926092
# 1980-12-19    0.096882   0.059238     0.982610
# ...                ...        ...          ...
# 2025-06-11  198.779999  -0.019380  2016.093489
# 2025-06-12  199.199997   0.002111  2020.353252
# 2025-06-13  196.449997  -0.013901  1992.461829
# 2025-06-16  198.419998   0.009978  2012.442242
# 2025-06-17  195.639999  -0.014110  1984.246561
#
# [11218 rows x 3 columns]

# %%
apple.cummreturns.plot(figsize=(12,8),title="APPLE buy and hold",fontsize=12)
# Out:
# <Axes: title={'center': 'APPLE buy and hold'}, xlabel='Date'>

# %%
apple.d_returns.mean()*252
# Out:
# 0.1705682499425287

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# 0.4473595859883796

# %%
#how to calculate drawdown (calculate max)

# %%
apple["cummmax"]=apple.cummreturns.cummax()

# %%
apple
# Out:
# Ticker            AAPL  d_returns  cummreturns       cummax      cummmax
# Date
# 1980-12-15    0.093453  -0.053581     0.947829     0.947829     0.947829
# 1980-12-16    0.086594  -0.076231     0.878261     0.947829     0.947829
# 1980-12-17    0.088737   0.024450     0.899999     0.947829     0.947829
# 1980-12-18    0.091310   0.028580     0.926092     0.947829     0.947829
# 1980-12-19    0.096882   0.059238     0.982610     0.982610     0.982610
# ...                ...        ...          ...          ...          ...
# 2025-06-11  198.779999  -0.019380  2016.093489  2620.745760  2620.745760
# 2025-06-12  199.199997   0.002111  2020.353252  2620.745760  2620.745760
# 2025-06-13  196.449997  -0.013901  1992.461829  2620.745760  2620.745760
# 2025-06-16  198.419998   0.009978  2012.442242  2620.745760  2620.745760
# 2025-06-17  195.639999  -0.014110  1984.246561  2620.745760  2620.745760
#
# [11218 rows x 5 columns]

# %%
apple[["cummreturns","cummmax"]].plot(figsize=(12,8),title="APPLE buy and hold",fontsize=12)
# Out:
# <Axes: title={'center': 'APPLE buy and hold'}, xlabel='Date'>

# %%
apple["drawdown"]=apple["cummmax"]-apple["cummreturns"]

# %%
apple
# Out:
# Ticker            AAPL  d_returns  cummreturns       cummax      cummmax  \
# Date
# 1980-12-15    0.093453  -0.053581     0.947829     0.947829     0.947829
# 1980-12-16    0.086594  -0.076231     0.878261     0.947829     0.947829
# 874.2943823868934

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2025-04-08 00:00:00')

# %%
apple.loc[(apple.index=='2025-04-08')]
# Out:
# Ticker            AAPL  d_returns  cummreturns     cummmax    drawdown
# Date
# 2025-04-08  172.194199  -0.051102  1746.451378  2620.74576  874.294382

# %%
apple.loc[(apple.index<='2025-04-08')]
# Out:
# Ticker            AAPL  d_returns  cummreturns      cummmax    drawdown
# Date
# 1980-12-15    0.093453  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.086594  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.088737   0.024450     0.899999     0.947829    0.047831
# 1980-12-18    0.091310   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.096882   0.059238     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2025-04-02  223.596786   0.003131  2267.793683  2620.745760  352.952077
# 2025-04-03  202.923904  -0.097013  2058.122372  2620.745760  562.623388
# 2025-04-04  188.133301  -0.075680  1908.111104  2620.745760  712.634656
# 2025-04-07  181.222366  -0.037426  1838.018086  2620.745760  782.727674
# 2025-04-08  172.194199  -0.051102  1746.451378  2620.745760  874.294382
#
# [11170 rows x 5 columns]

# %%
apple["drawdown%"]=(apple["cummmax"]-apple["cummreturns"])/apple["cummmax"]

# %%
apple
# Out:
# Ticker            AAPL  d_returns  cummreturns      cummmax    drawdown  \
# Date
# 1980-12-15    0.093453  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.086594  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.088737   0.024450     0.899999     0.947829    0.047831
# 1980-12-18    0.091310   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.096882   0.059238     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2025-06-11  198.779999  -0.019380  2016.093489  2620.745760  604.652271
# 2025-06-12  199.199997   0.002111  2020.353252  2620.745760  600.392508
# 2025-06-13  196.449997  -0.013901  1992.461829  2620.745760  628.283932
# 2025-06-16  198.419998   0.009978  2012.442242  2620.745760  608.303518
# 2025-06-17  195.639999  -0.014110  1984.246561  2620.745760  636.499199
#
# Ticker      drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# 1980-12-17   0.050463
# 1980-12-18   0.022934
# 1980-12-19   0.000000
# ...               ...
# 2025-06-11   0.230718
# 2025-06-12   0.229092
# 2025-06-13   0.239735
# 2025-06-16   0.232111
# 2025-06-17   0.242869
#
# [11218 rows x 6 columns]

# %%
apple["drawdown%"].max()
# Out:
# 0.8180144285655339

# %%
apple["drawdown%"].idxmax()
# Out:
# Timestamp('2003-04-17 00:00:00')

# %%
apple.loc[(apple.index=='2003-04-17')]
# Out:
# Ticker          AAPL  d_returns  cummreturns    cummmax  drawdown  drawdown%
# Date
# 2003-04-17  0.197156  -0.009105      1.99962  10.987792  8.988172   0.818014

# %%
apple.loc[(apple.index<='2003-04-17')]
# Out:
# Ticker          AAPL  d_returns  cummreturns    cummmax  drawdown  drawdown%
# Date
# 1980-12-15  0.093453  -0.053581     0.947829   0.947829  0.000000   0.000000
# 1980-12-16  0.086594  -0.076231     0.878261   0.947829  0.069569   0.073398
# 1980-12-17  0.088737   0.024450     0.899999   0.947829  0.047831   0.050463
# 1980-12-18  0.091310   0.028580     0.926092   0.947829  0.021738   0.022934
# 1980-12-19  0.096882   0.059238     0.982610   0.982610  0.000000   0.000000
# ...              ...        ...          ...        ...       ...        ...
# 2003-04-11  0.198357  -0.084927     2.011807  10.987792  8.975985   0.816905
# 2003-04-14  0.204068   0.028383     2.069725  10.987792  8.918066   0.811634
# 2003-04-15  0.201213  -0.014091     2.040766  10.987792  8.947026   0.814270
# 2003-04-16  0.198959  -0.011263     2.017910  10.987792  8.969882   0.816350
# 2003-04-17  0.197156  -0.009105     1.999620  10.987792  8.988172   0.818014
#
# [5641 rows x 6 columns]

# %%
#SMA Strategy

# %%
data=apple.AAPL.loc[(apple.index>='1991-01-01')]

# %%
data=data.to_frame()

# %%
data
# Out:
#                   AAPL
# Date
# 1991-01-02    0.309167
# 1991-01-03    0.305614
# 1991-01-04    0.307390
# 1991-01-07    0.307390
# 1991-01-08    0.307390
# ...                ...
# 2025-06-11  198.779999
# 2025-06-12  199.199997
# 2025-06-13  196.449997
# 2025-06-16  198.419998
# 2025-06-17  195.639999
#
# [8678 rows x 1 columns]

# %%
sma_s=50
sma_l=100

# %%
data["sma_s"]=data.AAPL.rolling(sma_s).mean()
data["sma_l"]=data.AAPL.rolling(sma_l).mean()

# %%
data.loc["2016"].plot(figsize=(12,8),title="AAPLE-SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12)
# Out:
# <Axes: title={'center': 'AAPLE-SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)
data
# Out:
#                   AAPL       sma_s       sma_l
# Date
# 1991-05-23    0.322214    0.426368    0.409260
# 1991-05-24    0.327569    0.423624    0.409444
# 1991-05-28    0.328461    0.420757    0.409673
# 1991-05-29    0.335602    0.417818    0.409955
# 1991-05-30    0.340064    0.414720    0.410281
# ...                ...         ...         ...
# 2025-06-11  198.779999  202.312253  216.092225
# 2025-06-12  199.199997  201.838299  215.789960
# 2025-06-13  196.449997  201.295363  215.533418
# 2025-06-16  198.419998  201.205285  215.284704
# 2025-06-17  195.639999  201.355419  215.009886
#
# [8579 rows x 3 columns]

# %%
data["position"]=np.where(data["sma_s"]>data["sma_l"],1,-1)
data
# Out:
#                   AAPL       sma_s       sma_l  position
# Date
# 1991-05-23    0.322214    0.426368    0.409260         1
# 1991-05-24    0.327569    0.423624    0.409444         1
# 1991-05-28    0.328461    0.420757    0.409673         1
# 1991-05-29    0.335602    0.417818    0.409955         1
# 1991-05-30    0.340064    0.414720    0.410281         1
# ...                ...         ...         ...       ...
# 2025-06-11  198.779999  202.312253  216.092225        -1
# 2025-06-12  199.199997  201.838299  215.789960        -1
# 2025-06-13  196.449997  201.295363  215.533418        -1
# 2025-06-16  198.419998  201.205285  215.284704        -1
# 2025-06-17  195.639999  201.355419  215.009886        -1
#
# [8579 rows x 4 columns]

# %%
data.loc["2016",["sma_s","sma_l","position"]].plot(figsize=(12,8),title="AAPLE-SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12,secondary_y="position")
# Out:
# <Axes: title={'center': 'AAPLE-SMA50 | SMA100'}, xlabel='Date'>

# %%
data["returnsb&h"]=np.log(data.AAPL.div(data.AAPL.shift(1)))

# %%
data["stragery"]=data["returnsb&h"]*data.position.shift(1)

# %%
data
# Out:
#                   AAPL       sma_s       sma_l  position  returnsb&h  stragery
# Date
# 1991-05-23    0.322214    0.426368    0.409260         1         NaN       NaN
# 1991-05-24    0.327569    0.423624    0.409444         1    0.016483  0.016483
# 1991-05-28    0.328461    0.420757    0.409673         1    0.002721  0.002721
# 1991-05-29    0.335602    0.417818    0.409955         1    0.021508  0.021508
# 1991-05-30    0.340064    0.414720    0.410281         1    0.013209  0.013209
# ...                ...         ...         ...       ...         ...       ...
# 2025-06-11  198.779999  202.312253  216.092225        -1   -0.019380  0.019380
# 2025-06-12  199.199997  201.838299  215.789960        -1    0.002111 -0.002111
# 2025-06-13  196.449997  201.295363  215.533418        -1   -0.013901  0.013901
# 2025-06-16  198.419998  201.205285  215.284704        -1    0.009978 -0.009978
# 2025-06-17  195.639999  201.355419  215.009886        -1   -0.014110  0.014110
#
# [8579 rows x 6 columns]

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h","stragery"]].sum()
# Out:
# returnsb&h    6.408817
# stragery      1.641192
# dtype: float64

# %%
data[["returnsb&h","stragery"]].sum().apply(np.exp)#what 1$ will be
# Out:
# returnsb&h    607.174941
# stragery        5.161319
# dtype: float64

# %%
data[["returnsb&h","stragery"]].std()*np.sqrt(252) #annual std
# Out:
# returnsb&h    0.429965
# stragery      0.430117
# dtype: float64

# %%
data.AAPL.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %%
## Strategy adjusted with long bias

# %%
data["position2"]=np.where(data["sma_s"]>data["sma_l"],1,0)

# %%
data["stragery2"]=data["returnsb&h"]*data.position2.shift(1)

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h","stragery2"]].sum()
# Out:
# returnsb&h    6.392334
# stragery2     4.008522
# dtype: float64

# %%
data[["returnsb&h","stragery2"]].sum()
# Out:
# returnsb&h    6.392334
# stragery2     4.008522
# dtype: float64

# %%
data[["returnsb&h","stragery2"]].std()*np.sqrt(252) #annual std
# Out:
# returnsb&h    0.429981
# stragery2     0.331500
# dtype: float64

# %%
##Stragery 2 better tahn Stragery 1

# %%
data[["stragery","stragery2"]].std()*np.sqrt(252) #annual std
# Out:
# stragery     0.430133
# stragery2    0.331500
# dtype: float64

# %%
#creating our first function

# %%
def test_stragery(stock,start,end,SMA):
    df=yf.download(stock,start=start,end=end)[['Close']]
    data=df
    data["return"]=np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"]=data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"]=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    
    data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
    data["stragery"]=data["return"]*data.position.shift(1)
    data.dropna(inplace=True)
    ret=np.exp(data["stragery"].sum())
    std=data["stragery"].std()*np.sqrt(252)
    
    return ret,std

# %%
test_stragery("SPY","2000-01-01","2020-01-01",(50,200))
# Out:
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/647836416.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df=yf.download(stock,start=start,end=end)[['Close']]
# [*********************100%***********************]  1 of 1 completed
# (1.5723008002851215e+65, 11.352598115539674)

# %%
##Create our first class

# %%
class SMABacktester():
    def __init__(self,symbol,SMA_S, SMA_L,start,end):
        self.symbol=symbol
        self.SMA_S=SMA_S
        self.SMA_L=SMA_L
        self.start=start
        self.end=end
        self.results=None
        self.get_data()
        
    def get_data(self):
        df=yf.download(self.symbol,start=self.start,end=self.end)[['Close']]
        data=df
        data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"]=data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"]=data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2=data
        
        return data
    
    def test_results(self):
        data=self.data2.copy().dropna()
        data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
        data["strategy"]=data["returns"]*data.position.shift(1)
        data.dropna(inplace=True)
        data["returnsbh"]=data["returns"].cumsum().apply(np.exp)
        data["returnsstrategy"]=data["strategy"].cumsum().apply(np.exp)
        perf=data["returnsstrategy"].iloc[-1]
        outperf=perf-data["returnsbh"].iloc[-1]
        self.results=data
        
        ret=np.exp(data["strategy"].sum())
        std= data["strategy"].std()*np.sqrt(252)
    
        #return ret,std
        return round(perf,6), round(outperf,6)
    
    def plot_results(self):
        if self.results is None:
            print("Run the test please")
        else:
            title="{}| SMA_S={} | SMA_L{}".format(self.symbol,self.SMA_S, self.SMA_L)
            self.results[["returnsbh","returnsstrategy"]].plot(title=title, figsize=(12,8))

# %%
tester= SMABacktester("SPY",50,100,"2000-01-01","2020-01-01")
# Out:
# /var/folders/4z/0p4c7jt52_d1bq34q6bc_x800000gn/T/ipykernel_55442/3791093128.py:12: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df=yf.download(self.symbol,start=self.start,end=self.end)[['Close']]
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (3.760704, 0.430816)

# %%
tester.plot_results()

# %%
class SMABacktester():
    def __init__(self,symbol,SMA_S, SMA_L,start,end):
        self.symbol=symbol
        self.SMA_S=SMA_S
        self.SMA_L=SMA_L
        self.start=start
        self.end=end
        self.results=None
        self.get_data()
        
    def get_data(self):
        df=yf.download(self.symbol,start=self.start,end=self.end)[['Close']]
        data=df
        data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"]=data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"]=data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2=data
        
        return data
    
    def test_results(self):
        data=self.data2.copy().dropna()
        data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
        data["strategy"]=data["returns"]*data.position.shift(1)
        data.dropna(inplace=True)
        data["returnsbh"]=data["returns"].cumsum().apply(np.exp)
        data["returnsstrategy"]=data["strategy"].cumsum().apply(np.exp)
        perf=data["returnsstrategy"].iloc[-1]
        outperf=perf-data["returnsbh"].iloc[-1]
        self.results=data
        
        ret=np.exp(data["strategy"].sum())
        std= data["strategy"].std()*np.sqrt(252)
    
        #return ret,std
        return round(perf,6), round(outperf,6)
    
    def plot_results(self):
        if self.results is None:
            print("Run the test please")
        else:
            title="{}| SMA_S={} | SMA_L{}".format(self.symbol,self.SMA_S, self.SMA_L)
            self.results[["returnsbh","returnsstrategy"]].plot(title=title, figsize=(12,8))
