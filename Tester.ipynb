# %%
from smabacktester import SMABacktester

# %%
tester=SMABacktester("AAPL",20,50,"2020-06-20","2025-06-20")
# Out:
# /Users/kenwong/Desktop/Algo trade/smabacktester.py:18: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.symbol, start=self.start, end=self.end)[['Close']]
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (0.578085, -0.986271)

# %% [markdown]
# # Assistant
# This error occurs because the Python interpreter cannot find the module `SMABacktester` that you're trying to import.
#
# The error message "NameError name 'null' is not defined" is a bit unusual and might be related to how the error is being displayed in your environment, but the core issue is that the module cannot be found.
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # Assistant
# This error occurs because the Python interpreter cannot find the module `SMABacktester` that you're trying to import.
#
# The error message "NameError name 'null' is not defined" is a bit unusual and might be related to how the error is being displayed in your environment, but the core issue is that the module cannot be found.
#
# Would you like me to provide the corrected code?
